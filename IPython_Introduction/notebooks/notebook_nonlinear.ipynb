# %%
message = ('IPython does not have to run from '
           'top to bottom')

# %%
message = 'Good luck debugging this'

# %%
print message
# Out:
# IPython does not have to run from top to bottom

# %%
print message
# Out:
# Good luck debugging this
